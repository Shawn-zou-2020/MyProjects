# %%
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
import pandas as pd 
import numpy as np
import geopandas as gpd
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster
import math

# %%
def embed_map(m, file_name):
    from IPython.display import IFrame
    m.save(file_name)
    return IFrame(file_name, width='100%', height='500px')

# %% [markdown]
# # Exercise

# %% [markdown]
# **Nominatim** refers to the geocoding software that will be used to generate locations.

# %%
geolocator = Nominatim(user_agent="zoux@usc.edu")

location = geolocator.geocode("Pyramid of Khufu",timeout=None)

print(location.point)
print(location.address)
# Out:
# 29 58m 44.976s N, 31 8m 3.17625s E
# هرم خوفو, شارع ابو الهول السياحي, نزلة البطران, الجيزة, 12125, مصر

# %%
point = location.point
print("Latitude:", point.latitude)
print("Longitude:", point.longitude)
# Out:
# Latitude: 29.97916
# Longitude: 31.134215625236113

# %%
universities = pd.read_csv("geospatial-learn-course-data/top_universities.csv")
universities.head()
# Out:
#                       Name
# 0     University of Oxford
# 1  University of Cambridge
# 2  Imperial College London
# 3               ETH Zurich
# 4                      UCL

# %%
def my_geocoder(row):
    try:
        geolocator = Nominatim(user_agent="zoux@usc.edu")
        point = geolocator.geocode(row,timeout=None).point
        return pd.Series({'Latitude':point.latitude,'Longitude':point.longitude})
    except:
        return None

# %%
universities[['Latitude', 'Longitude']] = universities.apply(lambda x: my_geocoder(x['Name']), axis=1)

# %%
print("{}% of addresses were geocoded!".format((1 - sum(np.isnan(universities["Latitude"])) / len(universities)) * 100))
# Out:
# 89.0% of addresses were geocoded!

# %%
# dropna
universities = universities.loc[~np.isnan(universities["Latitude"])]

# %%
universities = gpd.GeoDataFrame(universities, geometry=gpd.points_from_xy(universities.Longitude, universities.Latitude))
universities.crs = {'init': 'epsg:4326'}
universities.head()
# Out:
# /Users/shawnspokemonworld/anaconda3/lib/python3.9/site-packages/geopandas/array.py:170: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   return GeometryArray(vectorized.points_from_xy(x, y, z))
# /Users/shawnspokemonworld/anaconda3/lib/python3.9/site-packages/pyproj/crs/crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
#                       Name   Latitude  Longitude                   geometry
# 0     University of Oxford  51.758879  -1.259603  POINT (-1.25960 51.75888)
# 1  University of Cambridge  52.200623   0.110474   POINT (0.11047 52.20062)
# 2  Imperial College London  51.498959  -0.175641  POINT (-0.17564 51.49896)
# 3               ETH Zurich  47.562772   7.580947   POINT (7.58095 47.56277)
# 4                      UCL  51.521785  -0.135151  POINT (-0.13515 51.52179)

# %%
# Create a map
m = folium.Map(location=[54, 15], tiles='openstreetmap', zoom_start=2)

# Add points to the map
for idx, row in universities.iterrows():
    Marker([row['Latitude'], row['Longitude']], popup=row['Name']).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6e1d496faa8e80736f0295b79fef091 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6e1d496faa8e80736f0295b79fef091&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6e1d496faa8e80736f0295b79fef091 = L.map(
#                 &quot;map_a6e1d496faa8e80736f0295b79fef091&quot;,
#                 {
#                     center: [54.0, 15.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6653986240e5a2488d395257f4e838f4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a6e1d496faa8e80736f0295b79fef091);
#
#
#             var marker_15e10a9cab44f9d09044d5bc65474427 = L.marker(
#                 [51.758879050000004, -1.2596027863019],
#                 {}
#             ).addTo(map_a6e1d496faa8e80736f0295b79fef091);
#
#
#         var popup_da914c9bb4e07334006da52292efc37c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_25d5e47bc9ef626c7c0acc350ec5ec57 = $(`&lt;div id=&quot;html_25d5e47bc9ef626c7c0acc350ec5ec57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;University of Oxford&lt;/div&gt;`)[0];
#                 popup_da914c9bb4e07334006da52292efc37c.setContent(html_25d5e47bc9ef626c7c0acc350ec5ec57);
#
#
#
#         marker_15e10a9cab44f9d09044d5bc65474427.bindPopup(popup_da914c9bb4e07334006da52292efc37c)
#         ;
#
#
#
#
#             var marker_828ac5f455c5d7c316faa9980d6c23ff = L.marker(
#                 [52.2006233, 0.1104744],
#                 {}
#             ).addTo(map_a6e1d496faa8e80736f0295b79fef091);
#
#
#         var popup_af01c3ff102bc6c9c11370694f992ec2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_407870d90565efaffa0bc3f6dd88dea6 = $(`&lt;div id=&quot;html_407870d90565efaffa0bc3f6dd88dea6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;University of Cambridge&lt;/div&gt;`)[0];
#                 popup_af01c3ff102bc6c9c11370694f992ec2.setContent(html_407870d90565efaffa0bc3f6dd88dea6);
#
#
#
#         marker_828ac5f455c5d7c316faa9980d6c23ff.bindPopup(popup_af01c3ff102bc6c9c11370694f992ec2)
#         ;
#
#
#
#
#             var marker_9bf02c54cd8d51aeacf9bab8f02ac55f = L.marker(
#                 [51.4989595, -0.17564069276310426],
#                 {}
#             ).addTo(map_a6e1d496faa8e80736f0295b79fef091);
#
#
#         var popup_1036900b469e1f860afca42d1bc85754 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_87dca42c190cfa2fcd79bfdd2bf97868 = $(`&lt;div id=&quot;html_87dca42c190cfa2fcd79bfdd2bf97868&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Imperial College London&lt;/div&gt;`)[0];
#                 popup_1036900b469e1f860afca42d1bc85754.setContent(html_87dca42c190cfa2fcd79bfdd2bf97868);
#
#
#
#         marker_9bf02c54cd8d51aeacf9bab8f02ac55f.bindPopup(popup_1036900b469e1f860afca42d1bc85754)
#         ;
#
#
#
#
#             var marker_412bf7dae8732fcce6922d75fc7cc1d0 = L.marker(
#                 [47.56277165, 7.580947334069263],
#                 {}
#             ).addTo(map_a6e1d496faa8e80736f0295b79fef091);
#
#
#         var popup_dea28867b0a187cee2098fbedaf72bc0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fe88cb3b9c4e569732dfade5eb7dd148 = $(`&lt;div id=&quot;html_fe88cb3b9c4e569732dfade5eb7dd148&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ETH Zurich&lt;/div&gt;`)[0];
#                 popup_dea28867b0a187cee2098fbedaf72bc0.setContent(html_fe88cb3b9c4e569732dfade5eb7dd148);
#
#
#
#         marker_412bf7dae8732fcce6922d75fc7cc1d0.bindPopup(popup_dea28867b0a187cee2098fbedaf72bc0)
#         ;
#
#
#
#
#             var marker_bc7a4ce7347a6d64aaf6c4b188e2cc20 = L.marker(
#                 [51.5217852, -0.13515149671251314],
#                 {}
#             ).addTo(map_a6e1d496faa8e80736f0295b79fef091);
#
#
#         var popup_68ad932cb3714b46a08450d0ee1cae22 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_adbc1dc2dc74c6734813f46716fbeec9 = $(`&lt;div id=&quot;html_adbc1dc2dc74c6734813f46716fbeec9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UCL&lt;/div&gt;`)[0];
#                 popup_68ad932cb3714b46a08450d0ee1cae22.setContent(html_adbc1dc2dc74c6734813f46716fbeec9);
#
#
#
#         marker_bc7a4ce7347a6d64aaf6c4b188e2cc20.bindPopup(popup_68ad932cb3714b46a08450d0ee1cae22)
#         ;
#
#
#
#
#             var marker_74fe591eefe35c3c7f2cb2c98bd23877 = L.marker(

# %% [markdown]
# ## Join Tables

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
europe = world.loc[world.continent == 'Europe'].reset_index(drop=True)

europe_stats = europe[["name", "pop_est", "gdp_md_est"]]
europe_boundaries = europe[["name", "geometry"]]
# Out:
# /Users/shawnspokemonworld/anaconda3/lib/python3.9/site-packages/geopandas/_vectorized.py:142: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   aout[:] = out

# %%
europe_boundaries.head()
# Out:
#       name                                           geometry
# 0   Russia  MULTIPOLYGON (((178.725 71.099, 180.000 71.516...
# 1   Norway  MULTIPOLYGON (((15.143 79.674, 15.523 80.016, ...
# 2   France  MULTIPOLYGON (((-51.658 4.156, -52.249 3.241, ...
# 3   Sweden  POLYGON ((11.027 58.856, 11.468 59.432, 12.300...
# 4  Belarus  POLYGON ((28.177 56.169, 29.230 55.918, 29.372...

# %%
# Use an attribute join to merge data about countries in Europe
europe = europe_boundaries.merge(europe_stats, on="name")
europe.head()
# Out:
#       name                                           geometry    pop_est  \
# 0   Russia  MULTIPOLYGON (((178.725 71.099, 180.000 71.516...  142257519
# 1   Norway  MULTIPOLYGON (((15.143 79.674, 15.523 80.016, ...    5320045
# 2   France  MULTIPOLYGON (((-51.658 4.156, -52.249 3.241, ...   67106161
# 3   Sweden  POLYGON ((11.027 58.856, 11.468 59.432, 12.300...    9960487
# 4  Belarus  POLYGON ((28.177 56.169, 29.230 55.918, 29.372...    9549747
#
#    gdp_md_est
# 0   3745000.0
# 1    364700.0
# 2   2699000.0
# 3    498100.0
# 4    165400.0

# %%
# Use spatial join to match universities to countries in Europe
european_universities = gpd.sjoin(universities, europe)
european_universities.head()
# Out:
# /Users/shawnspokemonworld/anaconda3/lib/python3.9/site-packages/geopandas/tools/sjoin.py:59: UserWarning: CRS of frames being joined does not match!(+init=epsg:4326 +type=crs != epsg:4326)
#   warn(
# /Users/shawnspokemonworld/anaconda3/lib/python3.9/site-packages/geopandas/tools/sjoin.py:146: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   r_idx = np.concatenate([[i] * len(v) for i, v in idxmatch.iteritems()])
#                                                Name   Latitude  Longitude  \
# 0                              University of Oxford  51.758879  -1.259603
# 1                           University of Cambridge  52.200623   0.110474
# 2                           Imperial College London  51.498959  -0.175641
# 4                                               UCL  51.521785  -0.135151
# 5  London School of Economics and Political Science  51.514211  -0.116808
#
#                     geometry  index_right            name   pop_est  \
# 0  POINT (-1.25960 51.75888)           28  United Kingdom  64769452
# 1   POINT (0.11047 52.20062)           28  United Kingdom  64769452
# 2  POINT (-0.17564 51.49896)           28  United Kingdom  64769452
# 4  POINT (-0.13515 51.52179)           28  United Kingdom  64769452
# 5  POINT (-0.11681 51.51421)           28  United Kingdom  64769452
#
#    gdp_md_est
# 0   2788000.0
# 1   2788000.0
# 2   2788000.0
# 4   2788000.0
# 5   2788000.0

# %% [markdown]
# # Starbucks

# %% [markdown]
# ## Geocode the missing locations.

# %%
# Load and preview Starbucks locations in California
starbucks = pd.read_csv("geospatial-learn-course-data/starbucks_locations.csv")
starbucks.head()
# Out:
#    Store Number               Store Name  \
# 0  10429-100710       Palmdale & Hwy 395
# 1       635-352    Kanan & Thousand Oaks
# 2   74510-27669  Vons-Agoura Hills #2001
# 3  29839-255026    Target Anaheim T-0677
# 4  23463-230284   Safeway - Alameda 3281
#
#                                    Address          City  Longitude  Latitude
# 0             14136 US Hwy 395 Adelanto CA      Adelanto    -117.40     34.51
# 1                5827 Kanan Road Agoura CA        Agoura    -118.76     34.16
# 2           5671 Kanan Rd. Agoura Hills CA  Agoura Hills    -118.76     34.15
# 3  8148 E SANTA ANA CANYON ROAD AHAHEIM CA       AHAHEIM    -117.75     33.87
# 4               2600 5th Street Alameda CA       Alameda    -122.28     37.79

# %%
starbucks.isnull().sum()
# Out:
# Store Number    0
# Store Name      0
# Address         0
# City            0
# Longitude       5
# Latitude        5
# dtype: int64

# %%
starbucks.loc[starbucks.isnull()['Longitude']==True]
# Out:
#      Store Number                Store Name  \
# 153      5406-945  2224 Shattuck - Berkeley
# 154       570-512                Solano Ave
# 155  17877-164526   Safeway - Berkeley #691
# 156  19864-202264         Telegraph & Ashby
# 157     9217-9253           2128 Oxford St.
#
#                                Address      City  Longitude  Latitude
# 153   2224 Shattuck Avenue Berkeley CA  Berkeley        NaN       NaN
# 154     1799 Solano Avenue Berkeley CA  Berkeley        NaN       NaN
# 155    1444 Shattuck Place Berkeley CA  Berkeley        NaN       NaN
# 156  3001 Telegraph Avenue Berkeley CA  Berkeley        NaN       NaN
# 157     2128 Oxford Street Berkeley CA  Berkeley        NaN       NaN

# %%
def geo_stb(i):
    try: 
        geolocator = Nominatim(user_agent="zoux@usc.edu")
        location = geolocator.geocode(i,timeout=None)
        point = location.point
        return pd.Series({'Latitude':point.latitude,'Longitude':point.longitude})
    except:
        return None

# %%
starbucks.loc[starbucks.isnull()['Longitude']==True,['Longitude','Latitude']] = \
starbucks.loc[starbucks.isnull()['Longitude']==True].apply(lambda x: geo_stb(x['Address']), axis=1)

# %%
starbucks.isnull().sum()
# Out:
# Store Number    0
# Store Name      0
# Address         0
# City            0
# Longitude       0
# Latitude        0
# dtype: int64

# %% [markdown]
# ## View Berkeley locations

# %%
starbucks = gpd.GeoDataFrame(starbucks, geometry=gpd.points_from_xy(starbucks.Longitude, starbucks.Latitude))
starbucks.crs = {'init': 'epsg:4326'}
starbucks.head()
# Out:
# /Users/shawnspokemonworld/anaconda3/lib/python3.9/site-packages/geopandas/array.py:170: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   return GeometryArray(vectorized.points_from_xy(x, y, z))
# /Users/shawnspokemonworld/anaconda3/lib/python3.9/site-packages/pyproj/crs/crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
#    Store Number               Store Name  \
# 0  10429-100710       Palmdale & Hwy 395
# 1       635-352    Kanan & Thousand Oaks
# 2   74510-27669  Vons-Agoura Hills #2001
# 3  29839-255026    Target Anaheim T-0677
# 4  23463-230284   Safeway - Alameda 3281
#
#                                    Address          City  Longitude  Latitude  \
# 0             14136 US Hwy 395 Adelanto CA      Adelanto    -117.40     34.51
# 1                5827 Kanan Road Agoura CA        Agoura    -118.76     34.16
# 2           5671 Kanan Rd. Agoura Hills CA  Agoura Hills    -118.76     34.15
# 3  8148 E SANTA ANA CANYON ROAD AHAHEIM CA       AHAHEIM    -117.75     33.87
# 4               2600 5th Street Alameda CA       Alameda    -122.28     37.79
#
#                       geometry
# 0  POINT (-117.40000 34.51000)
# 1  POINT (-118.76000 34.16000)
# 2  POINT (-118.76000 34.15000)
# 3  POINT (-117.75000 33.87000)
# 4  POINT (-122.28000 37.79000)

# %%
m_2 = folium.Map(location=[37.88,-122.26], zoom_start=13)


# Add points to the map
for idx, row in starbucks.iterrows():
    Marker([row['Latitude'], row['Longitude']], popup=row['Store Name']).add_to(m_2)

# Display the map
m_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35fc40415c5ffd0b3f11d8de2e1e0751 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35fc40415c5ffd0b3f11d8de2e1e0751&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35fc40415c5ffd0b3f11d8de2e1e0751 = L.map(
#                 &quot;map_35fc40415c5ffd0b3f11d8de2e1e0751&quot;,
#                 {
#                     center: [37.88, -122.26],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0066cbd5734f19411d1adfcd75b792f3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_35fc40415c5ffd0b3f11d8de2e1e0751);
#
#
#             var marker_6415a00225cfe45d0ac9bf48916b2dc1 = L.marker(
#                 [34.51, -117.4],
#                 {}
#             ).addTo(map_35fc40415c5ffd0b3f11d8de2e1e0751);
#
#
#         var popup_41efca3c8d2fac6adccefca2fb059d3f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a2c6e46edfb037c0fe84f3ad4eec1813 = $(`&lt;div id=&quot;html_a2c6e46edfb037c0fe84f3ad4eec1813&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Palmdale &amp; Hwy 395&lt;/div&gt;`)[0];
#                 popup_41efca3c8d2fac6adccefca2fb059d3f.setContent(html_a2c6e46edfb037c0fe84f3ad4eec1813);
#
#
#
#         marker_6415a00225cfe45d0ac9bf48916b2dc1.bindPopup(popup_41efca3c8d2fac6adccefca2fb059d3f)
#         ;
#
#
#
#
#             var marker_0d04385952b13452c5052b29e02be24b = L.marker(
#                 [34.16, -118.76],
#                 {}
#             ).addTo(map_35fc40415c5ffd0b3f11d8de2e1e0751);
#
#
#         var popup_e967d6a4a3f1d47bd0c0985837be2e04 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_769723843b5782762e58858a3ffd8605 = $(`&lt;div id=&quot;html_769723843b5782762e58858a3ffd8605&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kanan &amp; Thousand Oaks&lt;/div&gt;`)[0];
#                 popup_e967d6a4a3f1d47bd0c0985837be2e04.setContent(html_769723843b5782762e58858a3ffd8605);
#
#
#
#         marker_0d04385952b13452c5052b29e02be24b.bindPopup(popup_e967d6a4a3f1d47bd0c0985837be2e04)
#         ;
#
#
#
#
#             var marker_7eb752496a35513958470df37d898d66 = L.marker(
#                 [34.15, -118.76],
#                 {}
#             ).addTo(map_35fc40415c5ffd0b3f11d8de2e1e0751);
#
#
#         var popup_b20f8bc548738db03c2ea18884f88909 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8468a0a29229e51213d41d1f415aa4c6 = $(`&lt;div id=&quot;html_8468a0a29229e51213d41d1f415aa4c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vons-Agoura Hills #2001&lt;/div&gt;`)[0];
#                 popup_b20f8bc548738db03c2ea18884f88909.setContent(html_8468a0a29229e51213d41d1f415aa4c6);
#
#
#
#         marker_7eb752496a35513958470df37d898d66.bindPopup(popup_b20f8bc548738db03c2ea18884f88909)
#         ;
#
#
#
#
#             var marker_8b7098315005a126be325fe08bc3cf2c = L.marker(
#                 [33.87, -117.75],
#                 {}
#             ).addTo(map_35fc40415c5ffd0b3f11d8de2e1e0751);
#
#
#         var popup_4ff96d6b5d97b52660a94b145a49f641 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_99af134c0d4220c7ec5833a0c0953da9 = $(`&lt;div id=&quot;html_99af134c0d4220c7ec5833a0c0953da9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Target Anaheim T-0677&lt;/div&gt;`)[0];
#                 popup_4ff96d6b5d97b52660a94b145a49f641.setContent(html_99af134c0d4220c7ec5833a0c0953da9);
#
#
#
#         marker_8b7098315005a126be325fe08bc3cf2c.bindPopup(popup_4ff96d6b5d97b52660a94b145a49f641)
#         ;
#
#
#
#
#             var marker_6a28e93bfd7f71c572e57c4595ea7a03 = L.marker(
#                 [37.79, -122.28],
#                 {}
#             ).addTo(map_35fc40415c5ffd0b3f11d8de2e1e0751);
#
#
#         var popup_488211d59ce17772c419434096ca7cb8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c5a38d928e0078123a9053af3dd07931 = $(`&lt;div id=&quot;html_c5a38d928e0078123a9053af3dd07931&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Safeway - Alameda 3281&lt;/div&gt;`)[0];
#                 popup_488211d59ce17772c419434096ca7cb8.setContent(html_c5a38d928e0078123a9053af3dd07931);
#
#
#
#         marker_6a28e93bfd7f71c572e57c4595ea7a03.bindPopup(popup_488211d59ce17772c419434096ca7cb8)
#         ;
#
#
#
#
#             var marker_b431f9dd103f165bf77fd33167525b63 = L.marker(
#                 [37.76, -122.24],

# %%
## Consoilidate the data

# %%
CA_counties = gpd.read_file("geospatial-learn-course-data/CA_county_boundaries/CA_county_boundaries/CA_county_boundaries.shp")
CA_counties.head()
# Out:
# /Users/shawnspokemonworld/anaconda3/lib/python3.9/site-packages/geopandas/_vectorized.py:142: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   aout[:] = out
#    GEOID                  name    area_sqkm  \
# 0   6091         Sierra County  2491.995494
# 1   6067     Sacramento County  2575.258262
# 2   6083  Santa Barbara County  9813.817958
# 3   6009      Calaveras County  2685.626726
# 4   6111        Ventura County  5719.321379
#
#                                             geometry
# 0  POLYGON ((-120.65560 39.69357, -120.65554 39.6...
# 1  POLYGON ((-121.18858 38.71431, -121.18732 38.7...
# 2  MULTIPOLYGON (((-120.58191 34.09856, -120.5822...
# 3  POLYGON ((-120.63095 38.34111, -120.63058 38.3...
# 4  MULTIPOLYGON (((-119.63631 33.27304, -119.6360...

# %%
CA_pop = pd.read_csv("geospatial-learn-course-data/CA_county_population.csv", index_col="GEOID")
CA_high_earners = pd.read_csv("geospatial-learn-course-data/CA_county_high_earners.csv", index_col="GEOID")
CA_median_age = pd.read_csv("geospatial-learn-course-data/CA_county_median_age.csv", index_col="GEOID")

# %%
cols = CA_pop.join([CA_high_earners, CA_median_age]).reset_index()
CA = CA_counties.merge(cols, on="GEOID")
CA.head()
# Out:
#    GEOID                  name    area_sqkm  \
# 0   6091         Sierra County  2491.995494
# 1   6067     Sacramento County  2575.258262
# 2   6083  Santa Barbara County  9813.817958
# 3   6009      Calaveras County  2685.626726
# 4   6111        Ventura County  5719.321379
#
#                                             geometry  population  \
# 0  POLYGON ((-120.65560 39.69357, -120.65554 39.6...        2987
# 1  POLYGON ((-121.18858 38.71431, -121.18732 38.7...     1540975
# 2  MULTIPOLYGON (((-120.58191 34.09856, -120.5822...      446527
# 3  POLYGON ((-120.63095 38.34111, -120.63058 38.3...       45602
# 4  MULTIPOLYGON (((-119.63631 33.27304, -119.6360...      850967
#
#    high_earners  median_age
# 0           111        55.0
# 1         65768        35.9
# 2         25231        33.7
# 3          2046        51.6
# 4         57121        37.5

# %%
CA["density"] = CA["population"] / CA["area_sqkm"]

# %% [markdown]
# ## Promising Counties

# %%
prom_counties = CA[((CA.high_earners > 100000) &
                         (CA.median_age < 38.5) &
                         (CA.density > 285) &
                         ((CA.median_age < 35.5) |
                         (CA.density > 1400) |
                         (CA.high_earners > 500000)))]

# %%
prom_counties.head()
# Out:
#     GEOID                  name     area_sqkm  \
# 5    6037    Los Angeles County  12305.376879
# 8    6073      San Diego County  11721.342229
# 10   6075  San Francisco County    600.588247
#
#                                              geometry  population  \
# 5   MULTIPOLYGON (((-118.66761 33.47749, -118.6682...    10105518
# 8   POLYGON ((-117.43744 33.17953, -117.44955 33.1...     3343364
# 10  MULTIPOLYGON (((-122.60025 37.80249, -122.6123...      883305
#
#     high_earners  median_age      density
# 5         501413        36.0   821.227834
# 8         194676        35.4   285.237299
# 10        114989        38.3  1470.733077

# %%
prom_loc = gpd.sjoin(starbucks, prom_counties)
len(prom_loc)
# Out:
# /Users/shawnspokemonworld/anaconda3/lib/python3.9/site-packages/geopandas/tools/sjoin.py:59: UserWarning: CRS of frames being joined does not match!(+init=epsg:4326 +type=crs != epsg:4326)
#   warn(
# /Users/shawnspokemonworld/anaconda3/lib/python3.9/site-packages/geopandas/tools/sjoin.py:136: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   l_idx = np.concatenate([[i] * len(v) for i, v in idxmatch.iteritems()])
# 1043

# %% [markdown]
# ## Visualization

# %%
m_3 = folium.Map(location=[37,-120], zoom_start=6)

mc = MarkerCluster()
# Add points to the map
for idx, row in prom_loc.iterrows():
    if not np.isnan(row['Longitude']) and not np.isnan(row['Latitude']):
        mc.add_child(folium.Marker([row['Latitude'], row['Longitude']]))

m_3.add_child(mc)
# Display the map
m_3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f61a1628658855d1f6b6948913b89d5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f61a1628658855d1f6b6948913b89d5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f61a1628658855d1f6b6948913b89d5b = L.map(
#                 &quot;map_f61a1628658855d1f6b6948913b89d5b&quot;,
#                 {
#                     center: [37.0, -120.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_144ac9b0cfd49a64951e9e0048a77715 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f61a1628658855d1f6b6948913b89d5b);
#
#
#             var marker_cluster_acc9c1e7d42e574eb6f2f2f4eea1ffe4 = L.markerClusterGroup(
#                 {}
#             );
#             map_f61a1628658855d1f6b6948913b89d5b.addLayer(marker_cluster_acc9c1e7d42e574eb6f2f2f4eea1ffe4);
#
#
#             var marker_c7f586d627b0851551017d9c1f47641f = L.marker(
#                 [34.16, -118.76],
#                 {}
#             ).addTo(marker_cluster_acc9c1e7d42e574eb6f2f2f4eea1ffe4);
#
#
#             var marker_e8f0763940fd225329ebb70543a83245 = L.marker(
#                 [34.15, -118.76],
#                 {}
#             ).addTo(marker_cluster_acc9c1e7d42e574eb6f2f2f4eea1ffe4);
#
#
#             var marker_145d711d2d01811343d3c3e6bf33915b = L.marker(
#                 [34.09, -118.14],
#                 {}
#             ).addTo(marker_cluster_acc9c1e7d42e574eb6f2f2f4eea1ffe4);
#
#
#             var marker_07a9d19273d95af6e59c4aaa1469a180 = L.marker(
#                 [34.08, -118.15],
#                 {}
#             ).addTo(marker_cluster_acc9c1e7d42e574eb6f2f2f4eea1ffe4);
#
#
#             var marker_3275cbb3951892c42eda3b43ba362edd = L.marker(
#                 [34.08, -118.13],
#                 {}
#             ).addTo(marker_cluster_acc9c1e7d42e574eb6f2f2f4eea1ffe4);
#
#
#             var marker_1c63d678498a230f8040d1a8d956e71d = L.marker(
#                 [34.09, -118.15],
#                 {}
#             ).addTo(marker_cluster_acc9c1e7d42e574eb6f2f2f4eea1ffe4);
#
#
#             var marker_ac16fc5503ce1a0691fe306ee06a8ae7 = L.marker(
#                 [34.08, -118.11],
#                 {}
#             ).addTo(marker_cluster_acc9c1e7d42e574eb6f2f2f4eea1ffe4);
#
#
#             var marker_67693658a72d6e09945ea94f34ea4af8 = L.marker(
#                 [34.09, -118.13],
#                 {}
#             ).addTo(marker_cluster_acc9c1e7d42e574eb6f2f2f4eea1ffe4);
#
#
#             var marker_8d9d7c563f94440413939fbc5fc046e6 = L.marker(
#                 [34.11, -118.02],
#                 {}
#             ).addTo(marker_cluster_acc9c1e7d42e574eb6f2f2f4eea1ffe4);
#
#
#             var marker_9db607ee8bc064280ec87541b58a1a43 = L.marker(
#                 [34.14, -118.02],
#                 {}
#             ).addTo(marker_cluster_acc9c1e7d42e574eb6f2f2f4eea1ffe4);
#
#
#             var marker_5c545bb6e6bb0f6e191e6fe453cc6f48 = L.marker(
#                 [34.13, -118.05],
#                 {}
#             ).addTo(marker_cluster_acc9c1e7d42e574eb6f2f2f4eea1ffe4);
#
#
#             var marker_ce88768210c0ab337431263183f888a2 = L.marker(
#                 [34.12, -118.06],
#                 {}
#             ).addTo(marker_cluster_acc9c1e7d42e574eb6f2f2f4eea1ffe4);
#
#
#             var marker_a20fa75d7f4dde651ccc8c149ebf3f8a = L.marker(
#                 [34.13, -118.07],
#                 {}
#             ).addTo(marker_cluster_acc9c1e7d42e574eb6f2f2f4eea1ffe4);
#
#
#             var marker_1d2974f7d42040bb1df2b4c87eec7d90 = L.marker(
#                 [34.14, -118.05],
#                 {}
#             ).addTo(marker_cluster_acc9c1e7d42e574eb6f2f2f4eea1ffe4);
#
#
#             var marker_8e1fa53b70f6578d2e1f7b923c50142f = L.marker(
#                 [33.87, -118.08],
#                 {}
#             ).addTo(marker_cluster_acc9c1e7d42e574eb6f2f2f4eea1ffe4);
#
#
#             var marker_cc33c7f6d2cdc33e3662ae2266dde2da = L.marker(
#                 [34.13, -117.89],
#                 {}
#             ).addTo(marker_cluster_acc9c1e7d42e574eb6f2f2f4eea1ffe4);
#
#
#             var marker_cd90f8ffc73eb29dfdf5488b1ab4ece4 = L.marker(
#                 [34.13, -117.93],
#                 {}
